# %% [markdown]
# # Customizing Matplotlib Graphs

# %% [markdown]
# ## Objectives

# %% [markdown]
# - To showcase the customization options available in Matplotlib for plotting.
# - To illustrate the versatility of visual representations, including line styles, colors, and marker options.
# - To demonstrate the use of subplots for organizing multiple plots within a single figure.
# - To introduce more advanced features like histograms, annotations, and two-dimensional histograms.

# %% [markdown]
# ## Background

# %% [markdown]
# Customizing Matplotlib explores the library's extensive customization capabilities, emphasizing how various graphical properties can be tailored to enhance plots' visual appeal and clarity. This guide aims to equip users with the skills to adjust virtually every plot element, from marker styles to subplot configurations.

# %% [markdown]
# ## Datasets Used

# %% [markdown]
# The notebook employs synthetic data generated on the fly using NumPy.

# %% [markdown]
# ## Customizing Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Suppose we want to plot 4 points: 2, 3, 5, 6

# %%
plt.plot([2, 3, 5, 6]);

# %% [markdown]
# We can specify two lists, `x` is the first, and `y` the second:

# %%
plt.plot([0, 1, 2, 3], [2, 3, 5, 6]);

# %% [markdown]
# Red circles

# %%
# red circles
plt.plot([0, 1, 2, 3], [2, 3, 5, 6], 'ro')
plt.axis([-0.1, 3.1, 0, 6.4]);

# %% [markdown]
# Green triangles

# %%
# green triangles
plt.plot([0, 1, 2, 3], [2, 3, 5, 6], 'g^')
plt.axis([-0.1, 3.1, 0, 6.4]);

# %% [markdown]
# Black squares

# %%
# black squares
plt.plot([0, 1, 2, 3], [2, 3, 5, 6], 'ks')
plt.axis([-0.1, 3.1, 0, 6.4]);

# %%
plt.plot([0, 1, 2, 3], [2, 3, 5, 6])
plt.plot([0, 1, 2, 3], [2, 3, 5, 6], 'bo')
plt.axis([-0.1, 3.1, 0, 6.4]);

# %% [markdown]
# Adding a title

# %%
plt.plot([0, 1, 2, 3], [2, 3, 5, 6])
plt.plot([0, 1, 2, 3], [2, 3, 5, 6], 'bo')
plt.axis([-0.1, 3.1, 0, 6.4])
plt.title('Four Points');

# %% [markdown]
# ## Creating subplots

# %% [markdown]
# To create subplots you must use `plt.subplot()`
#
# `plt.subplot(nrows, ncols, index)`
#
# `nrows` and `ncols` stand for the number of rows and number of columns respectively.
#
# - If you want a 2×2 grid, set `nrows=2` and `ncols=2`.
#
# - For a 3×1 grid, it is `nrows=3` and `ncols=1`.
#
# The index is the subplot you want to select.

# %%
# the data
names = ['A', 'B', 'C']
values = [5, 10, 30]

# total figure size
plt.figure(figsize=(15, 3))

# Defining subplots. We will have a matrix 1x4 (1 row and 4 columns)
plt.subplot(1, 4, 1)
plt.bar(names, values, alpha=0.8)
plt.axis([-1, 3, 0, 31])

plt.subplot(1, 4, 2)
plt.scatter(names, values)
plt.axis([-1, 3, 0, 31])

plt.subplot(1, 4, 3)
plt.plot(names, values)
plt.axis([-1, 3, 0, 31])

plt.subplot(1, 4, 4)
plt.pie(values, labels=names)

plt.suptitle('Bar, Scatter, Line, and Pie Charts')
plt.show()

# %%
names = ['A', 'B', 'C']
values = [5, 10, 30]
# total figure size 
plt.figure(figsize=(8,8))

# Defining subplots. We will have a matrix 2x2 (2 rows and 2 columns)
plt.subplot(221)
plt.bar(names, values, alpha=0.8)
plt.axis([-1, 3, 0, 31])

plt.subplot(222)
plt.scatter(names, values)
plt.axis([-1, 3, 0, 31])

plt.subplot(223)
plt.plot(names, values)
plt.axis([-1, 3, 0, 31])

plt.subplot(224)
plt.pie(values, labels=names)

plt.suptitle('Bar, Scatter, Line, and Pie Charts (2x2 Matrix)')
plt.show()

# %% [markdown]
# ## Histograms

# %% [markdown]
# Generating data:
#
#  `x` is normally distributed with mean `μ` and standard deviation `σ` (using Greek characters)

# %%
μ, σ = 100, 10
x = np.random.normal(μ, σ, 10000)

# %% [markdown]
# The histogram of the data:

# %%
plt.hist(x, facecolor='r', alpha=0.6);

# %% [markdown]
# ### Using the `bins` parameter

# %% [markdown]
# The "bin" in a histogram is the interval or spacing on the `x`-axis. A histogram counts the number of observations that fall into each of the disjoint categories (known as bins).
#
# Including `bins=20`

# %%
plt.hist(x, bins=20, facecolor='r', alpha=0.6);

# %% [markdown]
# Including `bins=50`

# %%
plt.hist(x, bins=50, facecolor='r', alpha=0.6);

# %% [markdown]
# ### Adding labels

# %% [markdown]
# `xlabel`, `ylabel` and `title` are used to add text in the indicated locations. Besides, you can add text in an arbitrary location.
#
# Adding `x` and `y` labels

# %%
plt.hist(x, bins=50, facecolor='r', alpha=0.6)
plt.xlabel('x values')
plt.ylabel('Frequency');

# %% [markdown]
# Modifying label atributes

# %%
plt.hist(x, bins=50, facecolor='r', alpha=0.6)
plt.xlabel('x values', fontweight='bold')
plt.ylabel('Frequency', fontweight='bold');

# %% [markdown]
# Adding a title

# %%
plt.hist(x, bins=50, facecolor='r', alpha=0.6)
plt.xlabel('x values', fontweight='bold')
plt.ylabel('Frequency', fontweight='bold')
plt.title('Histogram');

# %% [markdown]
# Modifying title

# %%
plt.hist(x, bins=50, facecolor='r', alpha=0.6)
plt.xlabel('x values', fontweight='bold')
plt.ylabel('Frequency', fontweight='bold')
plt.title('Histogram', loc='center', fontdict={'family': 'serif', 'size': 20,\
    'weight': 'normal', 'color': 'black'});

# %% [markdown]
# ### Adding text

# %% [markdown]
# You can add text to a Matplotlib chart with `plt.text`. You have to specify the coordinates.
#
# Adding a text (note how to create `μ` and `σ` using another method).
#
# Using `r`'string' (a Python `raw` string) allows to insert LaTeX commands into a Matplotlib chart.
#
# LaTeX commands are inserted between `$` pairs and everything between them will be rendered as in LaTeX.
#
# In LaTeX, `\mu` and `\sigma` are rendered as `μ` and `σ`.

# %%
plt.hist(x, bins=50, facecolor='r', alpha=0.6)
plt.xlabel('x values', fontweight='bold')
plt.ylabel('Frequency', fontweight='bold')
plt.title('Histogram', loc='center', fontdict={'family': 'serif', 'size': 20,\
    'weight': 'normal', 'color': 'black'})
# Adding text using LaTeX
plt.text(65, 500, r'$\mu=100,\sigma=10$');
# Adding text using Unicode Greek characters
plt.text(65, 400, 'μ= 100, σ= 10');

# %% [markdown]
# Modifying text attributes

# %%
plt.hist(x, bins=50, facecolor='r', alpha=0.6)
plt.xlabel('x values',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.title('Histogram', loc='center', fontdict={'family':'serif','size':20,\
    'weight':'normal','color':'black'})
plt.text(65, 500, 'μ= 100, σ= 10', fontdict={'size': 12,\
    'weight': 'bold', 'color': 'darkred'});

# %% [markdown]
# Modifying facecolor='g'

# %%
plt.hist(x, bins=50, facecolor='g', alpha=0.6)
plt.xlabel('x values',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.title('Histogram', loc='center', fontdict={'family':'serif','size':20,\
    'weight':'normal','color':'black'})
plt.text(65, 500, 'μ= 100, σ= 10', fontdict={'size': 12, \
    'weight': 'bold', 'color': 'darkgreen'});

# %% [markdown]
# Modifying facecolor='b'

# %%
plt.hist(x, bins=50, facecolor='b', alpha=0.6)
plt.xlabel('x values',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.title('Histogram', loc='center', fontdict={'family':'serif','size':20,\
    'weight':'normal','color':'black'})
plt.text(65, 500, 'μ= 100, σ= 10', fontdict={'size': 12, \
    'weight': 'bold', 'color': 'darkblue'});

# %% [markdown]
# `alpha` parameter is the opacity of the graph
#
# Modifying `alpha=0.4`

# %%
plt.hist(x, bins=50, facecolor='b', alpha=0.4)
plt.xlabel('x values',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.title('Histogram', loc='center', fontdict={'family': 'serif','size': 20,\
    'weight': 'normal','color': 'black'})
plt.text(65, 500, 'μ= 100, σ= 10', fontdict={'size': 12,\
    'weight': 'bold', 'color': 'darkblue'});

# %% [markdown]
# Modifying `alpha=0.2`

# %%
plt.hist(x, bins=50, facecolor='b', alpha=0.2)
plt.xlabel('x values',fontweight='bold')
plt.ylabel('Frequency',fontweight='bold')
plt.title('Histogram', loc='center', fontdict={'family': 'serif','size': 20,\
    'weight': 'normal','color': 'black'})
plt.text(65, 500, 'μ= 100, σ= 10', fontdict={'size': 12, \
    'weight': 'bold', 'color': 'darkblue'});

# %% [markdown]
# ## Two dimensional (bivariate) histograms

# %% [markdown]
# We can create histograms in two dimensions by dividing points among two-dimensional bins.

# %% [markdown]
# Generating data with multivariate normal distribution

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.grid(False)
plt.hist2d(x, y, bins=30, cmap='Greens');

# %% [markdown]
# Hexbins are a simple way of grouping two sets of numeric values into hexagonal bins.
#
# The hexbin() function is used to make a 2D hexagonal binning plot of points x, y.

# %%
plt.grid(False)
plt.hexbin(x, y, gridsize=30, cmap='Greens');

# %% [markdown]
# Changing colors

# %%
plt.grid(False)
plt.hexbin(x, y, gridsize=30, cmap='Blues');

# %% [markdown]
# ## Adding annotations with arrows

# %% [markdown]
# The uses of `text()` will place text at an arbitrary position on the Axes. A common use case of text is to annotate some feature of the plot, and the `annotate()` method provides helper functionality to make annotations easy.
#
# Let's use a different example:

# %%
x = np.arange(0.0, 6.0, 0.01)
y = np.sin(2*np.pi*x)
line, = plt.plot(x, y)

# Adding annotations
plt.annotate('local max', xy=(2.3, 1), xytext=(3, 1.5), arrowprops=dict(facecolor='darkgreen'),)
plt.annotate('local min', xy=(2.8, -1), xytext=(3.5, -1.5), arrowprops=dict(facecolor='darkred'),)

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Key Takeaways:
# - Matplotlib enables extensive customization of plot elements, allowing modifications to line styles, colors, and markers that enhance readability and aesthetic appeal.
# - The library supports the creation of complex subplot layouts, which can present multiple plots in a structured and informative manner.
# - Advanced plotting functions, such as histograms and two-dimensional histograms, offer powerful tools for statistical analysis, providing insights into data distributions and relationships.
# - Annotations and text additions are straightforward. They offer methods to highlight specific features or data points within plots, thereby enhancing the interpretability of graphs.

# %% [markdown]
# ## References

# %% [markdown]
# - VanderPlas, J. (2017) Python Data Science Handbook: Essential Tools for Working with Data. USA: O’Reilly Media, Inc. chapter 4
