# %% [markdown]
# # Categorical Plot in Seaborn

# %%
# !pip install numpy
# !pip install pandas
# !pip install seaborn

# %%
import seaborn as sns

# %%
# Apply the default theme
#sns.set_theme()

# %% [markdown]
# The `set_theme()` will affect how all matplotlib plots look, even if you don’t make them with seaborn.

# %% [markdown]
# Load an example dataset:

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Catplot is simplifies plotting that involves categorical variables. These plots offer different levels of granularity.

# %% [markdown]
# Categorical estimate plots with catplot
# - countplot() - with kind = 'count'
# - pointplot() – with kind = 'point'
# - barplot() – with kind = 'bar'

# %% [markdown]
# A count plot displays the number of observations in each category of your variable.

# %%
sns.catplot(data=tips, x="day", 
            kind='count');

# %% [markdown]
# Changing the order of categories:

# %%
category_order = ['Sat', 'Sun', 'Thur', 'Fri']

# %%
sns.catplot(data=tips, x="day", 
            kind='count', order=category_order);

# %% [markdown]
# A `point` plot shows mean estimate and uncertainty of the estimate with a point and error bar for each categorical variable.
#
# It is a great way to visualize the interaction between different variables.

# %%
# kind='point'
sns.catplot(data=tips, x="day", y="total_bill",
            kind='point', order=category_order);

# %% [markdown]
# Another popular choice for plotting categorical data is a bar plot.
#
# The height of each bar represents the mean value in each category.

# %%
# kind='bar'
sns.catplot(data=tips, x="day", y="total_bill",
            kind='bar', order=category_order);

# %% [markdown]
# Black lines at the top of each bar represent 95% confidence intervals for the mean. You can turn off confidence intervals setting the ci parameter to None.

# %%
# kind='bar' without confidence interval
sns.catplot(data=tips, x="day", y="total_bill",
            kind='bar', ci=None, order=category_order);

# %% [markdown]
# Categorical scatterplots with catplot
# - stripplot() – with kind=”strip”
# - swarmplot() – with kind=”swarm”

# %% [markdown]
# A `strip` is basically a scatter plot where the x axis represents a categorical variable.
#
# Typical uses of a strip plot involves applying a small random jitter value to each data point such that the separation between points becomes clearer.

# %%
# kind='strip' is the default value 
sns.catplot(data=tips, x="day", y="total_bill", 
            order=category_order);

# %% [markdown]
# Specifying kind='strip', we got the same results:

# %%
sns.catplot(data=tips, x="day", y="total_bill", 
            kind='strip', order=category_order);

# %% [markdown]
# The jitter parameter controls the magnitude of jitter or disables it altogether.
#
# We can specify jitter='False'

# %%
sns.catplot(data=tips, x="day", y="total_bill", 
            kind='strip', order=category_order, jitter=False);

# %% [markdown]
# Swarm plot (`kind='swarm'`) is a scatter plot that adjusts the positions of the points along the categorical axis so that they don’t overlap.

# %%
# kind='swarm'
sns.catplot(data=tips, x="day", y="total_bill",
            kind='swarm', order=category_order);

# %% [markdown]
# Categorical distribution plots with catplot
# - boxplot() – with kind=”box”
# - boxenplot() – with kind=”boxen”
# - violinplot() – with kind=”violin”

# %%
# kind='box'
sns.catplot(data=tips, x="day", y="total_bill",
            kind='box', order=category_order);

# %% [markdown]
# Black dots represent outliers. It is possible to turn off the outliers in a box plot by setting the sym parameter to an empty string.

# %%
sns.catplot(data=tips, x="day", y="total_bill",
            kind='box', order=category_order, sym='');

# %% [markdown]
# Boxenplot graph is an enhanced boxplot, because it shows a large number of quantiles. It is similar to box plot in graphing a nonparametric representation of a data distribution.

# %%
# kind='boxen'
sns.catplot(data=tips, x="day", y="total_bill",
            kind='boxen', order=category_order);

# %% [markdown]
# A violin plot is another method of plotting numeric data. It is similar to a box plot, with the addition of a rotated kernel density plot on each side.
#
# Violin plots are similar to box plots, except that they also show the probability density of the data at different values, usually smoothed by a kernel density estimator.

# %%
# kind='violin'
sns.catplot(data=tips, x="day", y="total_bill",
            kind='violin', order=category_order);

# %% [markdown]
# Including the `hue` parameter:

# %%
sns.catplot(data=tips, x="day", y="total_bill",
            order=category_order,
            hue='smoker');

# %%
sns.catplot(data=tips, x="day", y="total_bill",
            kind='swarm', order=category_order,
            hue='smoker');

# %%
sns.catplot(data=tips, x="day", y="total_bill",
            kind='box',  order=category_order,
            hue='smoker');

# %%
sns.catplot(data=tips, x="day", y="total_bill",
            kind='boxen',  order=category_order,
            hue='smoker');

# %%
sns.catplot(data=tips, x="day", y="total_bill",
            kind='violin', order=category_order,
            hue='smoker');

# %%
sns.catplot(data=tips, x="day", y="total_bill",
            kind='violin',  order=category_order,
            hue='smoker', split=True);

# %% [markdown]
# Changing the role of x and y:

# %%
sns.catplot(data=tips, y="day", x="total_bill",
            kind='violin',  order=category_order,
            hue='smoker', split=True);

# %%
sns.catplot(data=tips, x="day", y="total_bill",
            kind='point',  order=category_order,
            hue='smoker');

# %%
sns.catplot(data=tips, x="day", y="total_bill",
            kind='bar',  order=category_order,
            hue='smoker');

# %% [markdown]
# References:
# - VanderPlas, J. (2017) Python Data Science Handbook: Essential Tools for Working with Data. USA: O’Reilly Media, Inc. chapter 4
